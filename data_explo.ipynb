# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_soil = pd.read_excel('data/compiled data for analysis 050223.xlsx', sheet_name='r2_4')

# %%
df_soil
# Out:
#      Day  Rep Nutrient pathogen path_count  total_count    pH  EC mmhos/cm  \
# 0      0    2      HNS       LM   4.081834     7.326346  8.30        1.570
# 1      0    3      HNS       LM   3.669626     7.160333  8.20        1.240
# 2      0    4      HNS       LM    4.17931     6.789892  7.86        1.351
# 3      0    2      HNS     none          .     7.179709  8.30        1.570
# 4      0    3      HNS     none          .     7.197663  8.20        1.240
# ..   ...  ...      ...      ...        ...          ...   ...          ...
# 163   14    3      LNS      Sal   2.795755     5.227613  7.50        0.390
# 164   14    4      LNS      Sal   2.230449     5.280598  7.36        0.307
# 165   14    2      LNS     STEC   2.264458     4.837706  7.40        0.300
# 166   14    3      LNS     STEC   3.171527     5.233730  7.50        0.390
# 167   14    4      LNS     STEC   2.227422     5.254870  7.36        0.307
#
#      Alkalinity mg/kg CaCO3  Cl- (ppm)  ...  Mg (ppm)  Cu (ppm)  Fe (ppm)  \
# 0                     369.0     155.65  ...     16.75     0.060      7.18
# 1                     464.0     166.03  ...     18.50     0.070     10.80
# 2                     363.0     170.80  ...     18.00     0.090      0.84
# 3                     369.0     155.65  ...     16.75     0.060      7.18
# 4                     464.0     166.03  ...     18.50     0.070     10.80
# ..                      ...        ...  ...       ...       ...       ...
# 163                    52.0       4.10  ...     15.25     0.020      1.06
# 164                    31.0       2.97  ...     13.75     0.061      0.23
# 165                    37.0       2.49  ...     26.00     0.020      0.08
# 166                    52.0       4.10  ...     15.25     0.020      1.06
# 167                    31.0       2.97  ...     13.75     0.061      0.23
#
#      Mn (ppm)  Zn (ppm)  Dissolved P (ppm) Total P (ppm) Total N (%)  \
# 0         0.1      0.04          17.100789     18.261747    0.003648
# 1        0.16      0.05          17.886211     19.327961    0.005982
# 2        0.08      0.02          15.262157     18.995241    0.004961
# 3         0.1      0.04          17.100789     18.261747    0.003648
# 4        0.16      0.05          17.886211     19.327961    0.005982
# ..        ...       ...                ...           ...         ...
# 163      0.03         0           2.142051      1.935821    0.001167
# 164         0         0           1.071031      1.088899    0.002047
# 165      0.13         0           3.214492      1.786475    0.001313
# 166      0.03         0           2.142051      1.935821    0.001167
# 167         0         0           1.071031      1.088899    0.002047
#
#      Total N ppm      TOC
# 0      36.476562  118.500
# 1      59.821563  202.600
# 2      49.608125  118.400
# 3      36.476562  118.500
# 4      59.821563  202.600
# ..           ...      ...
# 163    11.672500   10.260
# 164    20.426875    7.744
# 165    13.131563    3.870
# 166    11.672500   10.260
# 167    20.426875    7.744
#
# [168 rows x 23 columns]

# %%
df_soil_none =  df_soil[df_soil['pathogen'] == 'none']

# %%
df_soil_none.drop(['path_count', 'total_count'], axis=1, inplace=True)
# Out:
# /var/folders/nb/x8ft0wb94sd72p6bpk_ld9fc0000gn/T/ipykernel_15455/3463991106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_soil_none.drop(['path_count', 'total_count'], axis=1, inplace=True)

# %%
df_soil_none
# Out:
#      Day  Rep Nutrient pathogen    pH  EC mmhos/cm  Alkalinity mg/kg CaCO3  \
# 3      0    2      HNS     none  8.30        1.570                   369.0
# 4      0    3      HNS     none  8.20        1.240                   464.0
# 5      0    4      HNS     none  7.86        1.351                   363.0
# 15     1    2      HNS     none  8.70        1.640                   395.0
# 16     1    3      HNS     none  8.40        1.940                   474.0
# 17     1    4      HNS     none  7.26        1.435                   326.0
# 27     4    2      HNS     none  8.70        1.590                   452.0
# 28     4    3      HNS     none  8.60        1.810                   457.0
# 29     4    4      HNS     none  6.94        1.477                   339.0
# 39     6    2      HNS     none  8.20        1.690                   430.0
# 40     6    3      HNS     none  8.60        1.880                   435.0
# 41     6    4      HNS     none  7.51        2.303                   292.0
# 51     8    2      HNS     none  8.40        1.690                   388.0
# 52     8    3      HNS     none  8.40        1.890                   478.0
# 53     8    4      HNS     none  7.66        2.275                   412.0
# 63    10    2      HNS     none  8.40        0.290                   345.0
# 64    10    3      HNS     none  7.90        1.940                   476.0
# 65    10    4      HNS     none  7.51        2.361                   434.0
# 75    14    2      HNS     none  8.00        1.660                   358.0
# 76    14    3      HNS     none  8.10        1.910                   482.0
# 77    14    4      HNS     none  8.06        2.299                   373.0
# 87     0    2      LNS     none  7.90        0.310                    42.0
# 88     0    3      LNS     none  8.10        0.390                    56.0
# 89     0    4      LNS     none  7.02        0.317                    22.0
# 99     1    2      LNS     none  7.90        0.330                    40.0
# 100    1    3      LNS     none  7.80        0.470                    56.0
# 101    1    4      LNS     none  7.35        0.314                    35.0
# 111    4    2      LNS     none  8.00        0.340                    46.0
# 112    4    3      LNS     none  7.90        0.390                    53.0
# 113    4    4      LNS     none  7.70        0.319                    34.0
# 123    6    2      LNS     none  8.00        0.360                    50.0
# 124    6    3      LNS     none  8.40        0.390                    54.0
# 125    6    4      LNS     none  7.05        0.318                    41.0
# 135    8    2      LNS     none  8.10        0.320                    42.0
# 136    8    3      LNS     none  8.20        0.380                    51.0
# 137    8    4      LNS     none  7.85        0.305                    34.0
# 147   10    2      LNS     none  7.80        0.310                    39.0
# 148   10    3      LNS     none  7.50        0.390                    41.0
# 149   10    4      LNS     none  7.34        0.304                    29.0
# 159   14    2      LNS     none  7.40        0.300                    37.0
# 160   14    3      LNS     none  7.50        0.390                    52.0
# 161   14    4      LNS     none  7.36        0.307                    31.0
#
#      Cl- (ppm)  K (ppm)  Na (ppm)  ...  Mg (ppm)  Cu (ppm)  Fe (ppm)  \
# 3       155.65    375.0     35.00  ...     16.75     0.060      7.18
# 4       166.03    512.5     40.00  ...     18.50     0.070     10.80
# 5       170.80    512.5     35.00  ...     18.00     0.090      0.84
# 15      159.19    337.5     35.00  ...     17.00     0.060      5.77
# 16      191.51    462.5     37.50  ...     18.50     0.080      9.29
# 17      166.90    412.5     31.15  ...     15.00     0.110      0.59
# 27      147.16    537.5     47.00  ...     24.25     0.070      6.84
# 28      179.24    525.0     37.50  ...     20.25     0.110      9.06
# 29      159.40    487.5     32.25  ...     15.50     0.107      0.92
# 39      153.77    662.5     72.50  ...     30.00     0.070      5.02
# 40      163.20    525.0     40.00  ...     21.25     0.130      9.38
# 41      174.52    512.5     35.10  ...     17.50     0.108      1.34
# 51      149.05    712.5     67.50  ...     31.25     0.060     15.40
# 52      161.32    525.0     40.00  ...     21.25     0.110      7.15
# 53      275.90    750.0     52.15  ...     26.00     0.105      3.52
# 63      125.46    375.0     50.00  ...     17.75     0.050      3.60
# 64      160.37    562.5     42.50  ...     22.25     0.130      7.22
# 65      254.71    600.0     52.45  ...     25.75     0.075      4.40
# 75      129.24    975.0     90.00  ...     44.50     0.080      5.84
# 76      151.88    512.5     40.00  ...     20.50     0.018      9.06
# 77      243.40    787.5     49.70  ...     24.25     0.102      3.18
# 87        3.20     12.0      6.00  ...     13.00     0.010      0.11
# 88        6.84     19.5      8.50  ...     18.25     0.010      1.12
# 89        3.82     15.0      6.75  ...     14.75     0.077      0.13
# 99        3.01     10.0      6.00  ...     12.75     0.010      0.05
# 100       4.76     18.5      9.00  ...     18.50     0.020      0.77
# 101       3.82     16.0      7.65  ...     12.25     0.070      0.03
# 111       5.61     18.5      8.50  ...     12.50     0.010      0.12
# 112       5.04     17.5      7.00  ...     15.00     0.030      1.23
# 113       2.78     34.5      8.80  ...     12.00     0.059      0.17
# 123       4.90     26.5     15.50  ...     27.25     0.040      0.15
# 124       5.04     19.5      7.00  ...     15.50     0.020      1.03
# 125       4.33     16.5      6.95  ...     13.50     0.036      0.12
# 135       3.01     31.5     15.50  ...     27.50     0.010      0.13
# 136       4.66     19.0      8.00  ...     14.75     0.070      0.74
# 137       3.11     17.5      8.40  ...     15.00     0.035      0.26
# 147       1.83     13.0     10.00  ...     11.50     0.010      0.12
# 148       4.10     17.5      7.00  ...     14.75     0.040      1.24
# 149       2.92     16.5      7.35  ...     13.75     0.028      0.14
# 159       2.49     28.5     16.00  ...     26.00     0.020      0.08
# 160       4.10     16.5      8.00  ...     15.25     0.020      1.06
# 161       2.97     18.0      8.95  ...     13.75     0.061      0.23
#
#      Mn (ppm) Zn (ppm) Dissolved P (ppm)  Total P (ppm)  Total N (%)  \
# 3         0.1     0.04         17.100789      18.261747     0.003648
# 4        0.16     0.05         17.886211      19.327961     0.005982
# 5        0.08     0.02         15.262157      18.995241     0.004961
# 15       0.11     0.11         16.351067      20.008523     0.004581
# 16       0.12     0.03         16.815180      18.148320     0.006391
# 17       0.06     0.02         14.387511      18.813758     0.004961
# 27       0.26     0.06         16.172562      17.983851     0.004815
# 28       0.21     0.05         19.492757      18.723017     0.007004
# 29       0.08     0.01         14.780222      19.055736     0.003502
# 39        0.2     0.05         16.636675      19.413031     0.004377
# 40       0.23     0.05         20.742293      20.477354     0.006128
# 41       0.09     0.02         15.601346      19.146577     0.004085
# 51       0.29     0.03         17.707706      19.611528     0.004377
# 52       0.15     0.03         18.421725      18.723016     0.005369
# 53        0.1     0.05         18.421726      22.594658     0.006420
# 63       0.21     0.02         16.101160      18.222047     0.004377
# 64       0.18     0.03         18.921541      20.658837     0.005544
# 65       0.12     0.03         19.242850      19.539691     0.007004
# 75       0.31     0.05         16.101160      20.286418     0.004815
# 76       0.27     0.05         21.741921      19.630432     0.007004
# 77       0.11     0.02         16.458170      18.934747     0.006129
# 87      <0.01    <0.01          2.783980       2.302568     0.000875
# 88      <0.01    <0.01          2.570473       2.480270     0.001021
# 89       0.03    <0.01          1.291537       2.450023     0.001459
# 99      <0.01    <0.01          2.841381       2.501065     0.000875
# 100       0.1    <0.01          2.570473       5.716721     0.001167
# 101      0.01      NaN          1.549844       2.419776     0.001459
# 111      0.06    <0.01          3.070988       4.247812     0.000875
# 112      0.01     0.02          2.284854       2.177798     0.001459
# 113         0        0          1.963556       2.419776     0.001313
# 123      0.08        0          2.783980       1.905574     0.001021
# 124      0.02        0          2.356267       1.512360     0.000875
# 125      0.01        0          1.999257       1.512360     0.001459
# 135      0.09        0          2.898783       1.198497     0.001313
# 136      0.02        0          2.106360       1.935821     0.000730
# 137      0.01        0          1.785051       1.603102     0.002918
# 147      0.11        0          2.669176       2.818661     0.000730
# 148      0.03        0          2.142061       2.177798     0.001606
# 149         0        0          2.356267       1.179641     0.001313
# 159      0.13        0          3.214492       1.786475     0.001313
# 160      0.03        0          2.142051       1.935821     0.001167
# 161         0        0          1.071031       1.088899     0.002047
#
#      Total N ppm      TOC
# 3      36.476562  118.500
# 4      59.821563  202.600
# 5      49.608125  118.400
# 15     45.814562   64.390
# 16     63.906937  198.300
# 17     49.608125  134.700
# 27     48.149063   89.220
# 28     58.362500  150.400
# 29     35.017500  136.300
# 39     43.771875   86.350
# 40     61.280625  163.900
# 41     40.853750  124.400
# 51     43.771875   99.230
# 52     53.693500  153.800
# 53     64.198750  192.200
# 63     43.771875   92.530
# 64     55.444375  164.500
# 65     70.035000  209.200
# 75     48.149063   85.630
# 76     70.035000  159.000
# 77     61.280625  167.900
# 87      8.754375    6.660
# 88     10.213437   11.730
# 89     14.590625    7.893
# 99      8.754375    8.450
# 100    11.672500   11.800
# 101    14.590625    8.120
# 111     8.754375    5.560
# 112    14.590625   12.130
# 113    13.131562    8.314
# 123    10.213437    5.830
# 124     8.754375   10.690
# 125    14.590625    7.669
# 135    13.131563    3.480
# 136     7.295312   10.450
# 137    29.181250    8.543
# 147     7.295313    4.600
# 148    16.049688   10.300
# 149    13.131562    8.062
# 159    13.131563    3.870
# 160    11.672500   10.260
# 161    20.426875    7.744
#
# [42 rows x 21 columns]

# %%
df_taxa = pd.read_excel('data/compiled taxa data for analysis 050223.xlsx', sheet_name='taxa_index')

# %%
df_taxa.head()
# Out:
#    Day  Rep Nutrient Pathogen taxa1     taxa2 taxa3 taxa4     taxa5 taxa6  \
# 0    0    2      HNS       LM     0  0.021511     0     0  0.083564     0
# 1    0    3      HNS       LM     0         0     0     0  0.039168     0
# 2    0    4      HNS       LM     0         0     0     0  0.016833     0
# 3    0    2      HNS     none     0  0.030896     0     0  0.066005     0
# 4    0    3      HNS     none     0         0     0     0  0.121501     0
#
#    ... taxa491   taxa492   taxa493   taxa494   taxa495 taxa496   taxa497  \
# 0  ...       0  0.006619  0.039713  0.494763  0.002482       0         0
# 1  ...       0         0  0.112607  0.553244         0       0  0.102815
# 2  ...       0         0  0.048815  0.070697  0.011783       0         0
# 3  ...       0         0  0.033705  0.362324         0       0  0.016852
# 4  ...       0  0.033029  0.058981  0.316138  0.004718       0         0
#
#   taxa498 taxa499 taxa500
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       0
# 4       0       0       0
#
# [5 rows x 504 columns]

# %%
df_taxa_none = df_taxa[df_taxa['Pathogen'] == 'none']

# %%
df_taxa_none.drop(['Day', 'Rep', 'Nutrient', 'Pathogen'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/matejamilicevic/Research/Food AI and Engineering/CPS/proposal/CPS/data_explo.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/matejamilicevic/Research/Food%20AI%20and%20Engineering/CPS/proposal/CPS/data_explo.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df_taxa_none.drop(['Day', 'Rep', 'Nutrient', 'Pathogen'], axis=1, inplace=True)
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Day', 'Rep', 'Nutrient', 'Pathogen'] not found in axis"

# %%
df = pd.concat([df_soil_none, df_taxa_none], axis=1)

# %%
df.drop(['pathogen'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df['Nutrient'] = labelencoder.fit_transform(df['Nutrient'])
# Out:
# /Users/matejamilicevic/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/matejamilicevic/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
for f in range(df.shape[0]):
    if np.issubdtype(df.iloc[f].values.dtype, np.number):
        print("All elements are numeric")
    else:
        print("Not all elements are numeric")
    break
# Out:
# Not all elements are numeric

# %%
df.to_csv('data/data.csv')

# %%
df = df.apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
df.corr()
# Out:
#                       Day           Rep      Nutrient        pH  EC mmhos/cm  \
# Day          1.000000e+00  1.012328e-16 -1.192308e-16 -0.112946     0.076458
# Rep          1.012328e-16  1.000000e+00  9.064933e-17 -0.592789     0.126098
# Nutrient    -1.192308e-16  9.064933e-17  1.000000e+00 -0.390632    -0.908510
# pH          -1.129460e-01 -5.927890e-01 -3.906320e-01  1.000000     0.308050
# EC mmhos/cm  7.645768e-02  1.260978e-01 -9.085100e-01  0.308050     1.000000
# ...                   ...           ...           ...       ...          ...
# taxa496               NaN           NaN           NaN       NaN          NaN
# taxa497     -2.080380e-01 -1.912730e-01 -1.561738e-01  0.135543     0.109864
# taxa498               NaN           NaN           NaN       NaN          NaN
# taxa499     -6.426049e-03 -1.140522e-01  2.317975e-01  0.145719    -0.204118
# taxa500               NaN           NaN           NaN       NaN          NaN
#
#              Alkalinity mg/kg CaCO3  Cl- (ppm)   K (ppm)  Na (ppm)  Ca (ppm)  \
# Day                        0.008168   0.026182  0.165401  0.218136  0.121069
# Rep                       -0.041870   0.139836  0.008253 -0.181245 -0.267044
# Nutrient                  -0.976740  -0.953592 -0.931086 -0.870352  0.785809
# pH                         0.471713   0.304424  0.333456  0.389310 -0.214794
# EC mmhos/cm                0.908578   0.949040  0.908083  0.795996 -0.708487
# ...                             ...        ...       ...       ...       ...
# taxa496                         NaN        NaN       NaN       NaN       NaN
# taxa497                    0.120945   0.117934  0.047592  0.056241 -0.129232
# taxa498                         NaN        NaN       NaN       NaN       NaN
# taxa499                   -0.216587  -0.218188 -0.215200 -0.209188  0.183390
# taxa500                         NaN        NaN       NaN       NaN       NaN
#
#              ...   taxa491   taxa492   taxa493   taxa494   taxa495  taxa496  \
# Day          ... -0.004838  0.524912 -0.377296  0.143950  0.417601      NaN
# Rep          ...  0.191273  0.016902  0.032740 -0.223508 -0.088174      NaN
# Nutrient     ... -0.156174  0.430815 -0.279136  0.085655  0.450582      NaN
# pH           ... -0.133274 -0.348205  0.168134  0.057504 -0.261608      NaN
# EC mmhos/cm  ...  0.260555 -0.399908  0.144069 -0.116001 -0.419088      NaN
# ...          ...       ...       ...       ...       ...       ...      ...
# taxa496      ...       NaN       NaN       NaN       NaN       NaN      NaN
# taxa497      ... -0.024390 -0.068106  0.341121  0.275617 -0.072414      NaN
# taxa498      ...       NaN       NaN       NaN       NaN       NaN      NaN
# taxa499      ... -0.036201  0.021043 -0.087370  0.126473 -0.033588      NaN
# taxa500      ...       NaN       NaN       NaN       NaN       NaN      NaN
#
#               taxa497  taxa498   taxa499  taxa500
# Day         -0.208038      NaN -0.006426      NaN
# Rep         -0.191273      NaN -0.114052      NaN
# Nutrient    -0.156174      NaN  0.231797      NaN
# pH           0.135543      NaN  0.145719      NaN
# EC mmhos/cm  0.109864      NaN -0.204118      NaN
# ...               ...      ...       ...      ...
# taxa496           NaN      NaN       NaN      NaN
# taxa497      1.000000      NaN -0.036201      NaN
# taxa498           NaN      NaN       NaN      NaN
# taxa499     -0.036201      NaN  1.000000      NaN
# taxa500           NaN      NaN       NaN      NaN
#
# [520 rows x 520 columns]

# %%
mask1 = df['Nutrient'] == 0
mask2 = df['Rep'] == 2
plt.plot(df[ mask1& mask2]['Day'], df[mask1&mask2]['Alkalinity mg/kg CaCO3'])

# %%
for rep in pd.unique(df['Rep']):
    mask1 = df['Nutrient'] == 0
    mask2 = df['Rep'] == rep
    plt.scatter(df[mask1&mask2]['K (ppm)'], df[ mask1& mask2]['taxa410'], label=f'Rep:{rep}')
plt.legend()
plt.show()

# %%
df[ mask1& mask2]['taxa410']
# Out:
# 3     0.966197
# 15    0.427518
# 27    0.941496
# 39    3.479164
# 51    5.625546
# 63    0.000000
# 75    0.000000
# Name: taxa410, dtype: float64

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class NNModel(nn.Module):
    def __init__(self, input_size = 100, out_features=5):
        super(NNModel, self).__init__()
        
        self.fc1 = nn.Linear(in_features=input_size, out_features=input_size)
        self.fc2 = nn.Linear(in_features=input_size, out_features=out_features)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
df.columns[:20]
# Out:
# Index(['Day', 'Rep', 'Nutrient', 'pH', 'EC mmhos/cm', 'Alkalinity mg/kg CaCO3',
#        'Cl- (ppm)', 'K (ppm)', 'Na (ppm)', 'Ca (ppm)', 'Mg (ppm)', 'Cu (ppm)',
#        'Fe (ppm)', 'Mn (ppm)', 'Zn (ppm)', 'Dissolved P (ppm)',
#        'Total P (ppm)', 'Total N (%)', 'Total N ppm', 'TOC'],
#       dtype='object')

# %%
data = df.drop(df.columns[:20], axis=1)
y = df[df.columns[3:20]]

# %%
data.head()
# Out:
#        taxa2  taxa3  taxa4     taxa5  taxa6  taxa7  taxa8     taxa9    taxa10  \
# 3   0.030896    0.0    0.0  0.066005    0.0    0.0    0.0  0.043535  0.009830
# 4   0.000000    0.0    0.0  0.121501    0.0    0.0    0.0  0.000000  0.036568
# 5   0.000000    0.0    0.0  0.021147    0.0    0.0    0.0  0.055511  0.017182
# 15  0.007468    0.0    0.0  0.033604    0.0    0.0    0.0  0.003734  0.003734
# 16  0.000000    0.0    0.0  0.000000    0.0    0.0    0.0  0.000000  0.006285
#
#     taxa11  ...  taxa491   taxa492   taxa493   taxa494   taxa495  taxa496  \
# 3      0.0  ...      0.0  0.000000  0.033705  0.362324  0.000000      0.0
# 4      0.0  ...      0.0  0.033029  0.058981  0.316138  0.004718      0.0
# 5      0.0  ...      0.0  0.000000  0.052207  0.181071  0.007269      0.0
# 15     0.0  ...      0.0  0.000000  0.007468  0.179222  0.000000      0.0
# 16     0.0  ...      0.0  0.000000  0.000000  0.026397  0.000000      0.0
#
#      taxa497  taxa498  taxa499  taxa500
# 3   0.016852      0.0      0.0      0.0
# 4   0.000000      0.0      0.0      0.0
# 5   0.000000      0.0      0.0      0.0
# 15  0.000000      0.0      0.0      0.0
# 16  0.000000      0.0      0.0      0.0
#
# [5 rows x 499 columns]

# %%
y.shape
# Out:
# (42, 17)

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
X = torch.tensor(data.values, dtype=torch.float32)
y = torch.tensor(y.values, dtype=torch.float32)

# %%
model = NNModel(25, 17)

# %%
import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.00001, momentum=0.9)

# %%
X_train, X_test, y_train, y_test = train_test_split(principalComponents, y, test_size=0.4, random_state=42)

# %%
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/matejamilicevic/Research/Food AI and Engineering/CPS/proposal/CPS/data_explo.ipynb Cell 33 line 1
# ----> <a href='vscode-notebook-cell:/Users/matejamilicevic/Research/Food%20AI%20and%20Engineering/CPS/proposal/CPS/data_explo.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> train_dataset = TensorDataset(X_train, y_train)
#       <a href='vscode-notebook-cell:/Users/matejamilicevic/Research/Food%20AI%20and%20Engineering/CPS/proposal/CPS/data_explo.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a> test_dataset = TensorDataset(X_test, y_test)
#       <a href='vscode-notebook-cell:/Users/matejamilicevic/Research/Food%20AI%20and%20Engineering/CPS/proposal/CPS/data_explo.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/torch/utils/data/dataset.py:204, in TensorDataset.__init__(self, *tensors)
#     203 def __init__(self, *tensors: Tensor) -> None:
# --> 204     assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     205     self.tensors = tensors
#
# File ~/anaconda3/envs/kaggle_comps/lib/python3.11/site-packages/torch/utils/data/dataset.py:204, in <genexpr>(.0)
#     203 def __init__(self, *tensors: Tensor) -> None:
# --> 204     assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors), "Size mismatch between tensors"
#     205     self.tensors = tensors
#
# TypeError: 'int' object is not callable

# %%
n=0
plt.boxplot([y_test[:,n], all_predictions[:,n]], labels=['Actual', 'Predicted'])
plt.title(df.columns[n+3])
# Out:
# Text(0.5, 1.0, 'pH')

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
X_standardized = StandardScaler().fit_transform(X)

# %%
pca = PCA(0.95)
principalComponents = pca.fit_transform(X)

# %%
principalComponents.shape
# Out:
# (42, 4)

# %%
principalComponents
# Out:
# array([[  5.981045  , -15.0558084 ,  21.67120386, -10.10579149],
#        [  3.90769896, -10.2514747 ,   6.5671637 ,  -9.31242361],
#        [ -0.90422066, -21.60864593,  36.58050688, -10.80242557],
#        [ 20.70587902,  -7.21762943,   8.54971207,  11.6348213 ],
#        [ 29.95600618,  -1.38936315,   9.15338591, -12.06620064],
#        [ 25.77443241,  -1.48805348,   0.83518285,  13.97970066],
#        [ 38.84249613,   4.21962113,  -5.10329692,   5.694498  ],
#        [ 52.11562809,  11.6663077 ,  -9.94080389, -10.70127782],
#        [ 22.79404604,  -2.26308665,   2.56116537,  13.15216583],
#        [ 31.67068897,   2.90195199,  -2.04231961,   5.74443134],
#        [ 52.77674692,  11.46921934, -11.23268508, -12.17457185],
#        [ 21.76525089,   4.60910955,  -0.80233805,   6.26006321],
#        [ 16.88162662,  -2.25077498,   4.94528309,   8.47893432],
#        [ 53.19276484,  11.51308195,  -9.94794324, -12.8150502 ],
#        [ 19.24522358,   0.38112785,   3.30178033,  15.70106576],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [ 34.0776103 ,   3.8409683 ,   0.89699705,  -2.7365527 ],
#        [ 15.50518972,  -1.58331264,   3.96854076,  15.05222564],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [ 11.07819257,  -1.95017688,   3.18289185,  -1.87619008],
#        [ 16.82551442,  -2.73147179,   7.56644595,   7.2806663 ],
#        [-25.65199342,   4.8042912 ,   0.30779316,  -1.02748497],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-25.86982925,   4.25255772,   1.58247555,  -1.29395062],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-21.01194191,  21.34969554,   0.43536791,  -1.4300936 ],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-30.1633743 ,  17.75398306,   3.36289916,  -0.06604531],
#        [-11.5987113 ,  12.88187775,  -1.0512122 ,  -3.2676423 ],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-28.88723961,  19.01995529,   2.28652272,   0.0910497 ],
#        [ -0.5745034 ,   7.64225459,  -5.66937551,  -5.38967928],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-30.13283414,  16.77844204,   2.14670241,  -0.20090987],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-16.7445034 , -19.72188076,  -8.40160492,  -0.82539946],
#        [-28.2312001 ,  16.00671029,   1.40313838,   0.83033784],
#        [-30.22196389,  23.50634038,   2.84621983,   1.10616342],
#        [-31.05104288,  23.26146862,   2.90154998,   1.58128301],
#        [-25.97261363,   8.2125254 ,   0.18261334,   0.94018864],
#        [-19.41461788,   0.3261367 ,  -3.03178607,  -1.66574799],
#        [-12.70942371,  18.88909844,  -2.79933723,  -3.16696194]])

# %%
X_train, X_test, y_train, y_test = train_test_split(principalComponents, y, test_size=0.2, random_state=42)

# %%
y_train
# Out:
# tensor([[8.7000e+00, 1.5900e+00, 4.5200e+02, 1.4716e+02, 5.3750e+02, 4.7000e+01,
#          3.8000e+00, 2.4250e+01, 7.0000e-02, 6.8400e+00, 2.6000e-01, 6.0000e-02,
#          1.6458e+01, 1.8935e+01, 6.1286e-03, 6.1281e+01, 1.6790e+02],
#         [8.6000e+00, 1.8100e+00, 4.5700e+02, 1.7924e+02, 5.2500e+02, 3.7500e+01,
#          4.3000e+00, 2.0250e+01, 1.1000e-01, 9.0600e+00, 2.1000e-01, 5.0000e-02,
#          1.9493e+01, 1.8723e+01, 7.0035e-03, 5.8362e+01, 1.5040e+02],
#         [7.6600e+00, 2.2750e+00, 4.1200e+02, 2.7590e+02, 7.5000e+02, 5.2150e+01,
#          4.8000e+00, 2.6000e+01, 1.0500e-01, 3.5200e+00, 1.0000e-01, 5.0000e-02,
#          1.8422e+01, 2.2595e+01, 6.4198e-03, 6.4199e+01, 1.9220e+02],
#         [7.9000e+00, 3.9000e-01, 5.3000e+01, 5.0400e+00, 1.7500e+01, 7.0000e+00,
#          3.4500e+01, 1.5000e+01, 3.0000e-02, 1.2300e+00, 1.0000e-02, 2.0000e-02,
#          2.2849e+00, 2.1778e+00, 1.4590e-03, 1.4591e+01, 1.2130e+01],
#         [7.3400e+00, 3.0400e-01, 2.9000e+01, 2.9200e+00, 1.6500e+01, 7.3500e+00,
#          2.4000e+01, 1.3750e+01, 2.8000e-02, 1.4000e-01, 0.0000e+00, 0.0000e+00,
#          2.3563e+00, 1.1796e+00, 1.3132e-03, 1.3132e+01, 8.0620e+00]])

# %%
X = torch.tensor(X_train, dtype=torch.float32)

# %%
train_dataset = TensorDataset(X, y_train)
test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), y_test)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=10, shuffle=False)

# %%
X.shape
# Out:
# torch.Size([33, 4])

# %%
class MeanSquaredLogarithmicError(nn.Module):
    def __init__(self):
        super(MeanSquaredLogarithmicError, self).__init__()

    def forward(self, y_pred, y_true):
        y_pred = torch.clamp(y_pred, min=0)
        y_true = torch.clamp(y_true, min=0)
        
        return torch.mean((torch.log1p(y_true) - torch.log1p(y_pred)) ** 2)

# %%
import torch.nn as nn
import torch.nn.functional as F

class NNModel(nn.Module):
    def __init__(self, input_size=100, out_features=5):
        super(NNModel, self).__init__()
        self.fc1 = nn.Linear(in_features=input_size, out_features=50)
        self.bn1 = nn.BatchNorm1d(50)
        self.fc2 = nn.Linear(in_features=50, out_features=50)
        self.bn2 = nn.BatchNorm1d(50)
        self.fc3 = nn.Linear(in_features=50, out_features=out_features)
        self.dropout = nn.Dropout(0.2)  # Example dropout, adjust the rate as needed

    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = F.relu(self.fc3(x))  # ReLU activation at the output layer
        return x

# %%
model = torch.load('model.pth')

# %%
import torch.optim as optim
#model = NNModel(4, 17)
criterion = MeanSquaredLogarithmicError()
optimizer = optim.Adam(model.parameters(), lr=0.000001)

# %%
from sklearn.model_selection import KFold
model.train()
# Assuming you have your dataset X, y
kf = KFold(n_splits=2) # Example of 5-fold cross-validation

for fold, (train_index, val_index) in enumerate(kf.split(X)):
    print(f'Fold {fold+1}')

    X_train, X_val = X[train_index], X[val_index]
    y_t, y_v = y_train[train_index], y_train[val_index]

    for epoch in range(50):  # 100 epochs
        optimizer.zero_grad()
        
        outputs = model(X_train)
        loss = criterion(outputs, y_t)
        loss.backward()
        optimizer.step()
        
        # Validation step
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y
        all_predictions.extend(outputs)
        all_labels.extend(labels)


all_predictions = torch.stack(all_predictions)
all_labels = torch.stack(all_labels)

# %%
n = 0
plt.scatter([x for x in range(y_test.shape[0])], y_test[:,n], label='Actual')
plt.scatter([x for x in range(y_test.shape[0])], all_predictions[:,n], label='Predicted')
plt.xlabel('Index')
plt.ylabel(df.columns[n+3])
plt.legend()
plt.show()

# %%
n=16
plt.boxplot([y_test[:,n], all_predictions[:,n]], labels=['Actual', 'Pred'])
plt.title(df.columns[n+3])
# Out:
# Text(0.5, 1.0, 'TOC')

# %%
torch.save(model, 'model_rmsle.pth')
torch.save(all_predictions, 'pred_rmsle.pt')
torch.save(y_test, 'actual_rmsle.pt')

# %% [markdown]
# # SVM-Regressor, RF, LGBM, etcc.

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
import re
def format_filename(filename):
    """
    Formats the given filename to remove special characters that
    might interfere with directory structures.
    """
    # Replace forbidden characters with an underscore
    filename = re.sub(r'[\\/*?:"<>|]', '_', filename)
    
    # Replace spaces with underscores
    filename = filename.replace(' ', '_')

    return filename

# %%
def fit_svr(i, X, y_train, X_test, y_test):    
    svr = SVR()

# Define the parameter grid
    param_grid = {
        'C': [0.1, 1, 10, 100],         # Regularization parameter
        'gamma': ['scale', 'auto'],     # Kernel coefficient
        'kernel': ['rbf', 'linear', 'poly'],    # Specifies the kernel type to be used
    }

    # Setup GridSearchCV
    grid_search = GridSearchCV(estimator=svr, param_grid=param_grid, 
                            cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

    # Perform grid search
    grid_search.fit(X, y_train[:,i])

    # Print the best parameters and the best score
    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best score: {-grid_search.best_score_}")

    # Evaluate on the test set
    best_model = grid_search.best_estimator_
    test_score = best_model.score(X_test, y_test[:,i])
    y_pred = best_model.predict(X_test)
    #y_pred = [np.average([y_pred[j], all_predictions[j,0]]) for j, x in enumerate(y_pred)]
    print(f"Test set score: {test_score}")
    plt.boxplot([y_test[:,i], y_pred], labels=['Actual', 'Pred'])
    plt.title(f'SVR-{df.columns[i+3]} RMSE : {np.sqrt(mean_squared_error(y_test[:,i], y_pred))}')
    
    plt.savefig(f'plots/svr_{format_filename(df.columns[i+3])}')
    plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
def fit_rf(i, X, y_train, X_test, y_test):
    rf = RandomForestRegressor(random_state=42)


    param_grid_rf = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    }

    grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, 
                                cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')


    grid_search_rf.fit(X, y_train[:,i])


    print(f"Best parameters (RF): {grid_search_rf.best_params_}")
    print(f"Best score (RF): {-grid_search_rf.best_score_}")


    best_rf = grid_search_rf.best_estimator_
    test_score_rf = best_rf.score(X_test, y_test[:,i])
    print(f"Test set score (RF): {test_score_rf}")
    y_pred_rf = best_rf.predict(X_test)
    plt.boxplot([y_test[:,i], y_pred_rf], labels=['Actual', 'Pred'])
    plt.title(f'RF-{df.columns[i+3]} RMSE : {np.sqrt(mean_squared_error(y_test[:,i], y_pred_rf))}')
    
    plt.savefig(f'plots/rf_{format_filename(df.columns[i+3])}.png')
    plt.show()

# %%
from lightgbm import LGBMRegressor
def fit_lgbm(i, X, y_train, X_test, y_test):
    lgbm = LGBMRegressor(random_state=42)

    # Define the parameter grid
    param_grid_lgbm = {
        'num_leaves': [2,3,5,10,20,31, 50, 70],
        'learning_rate': [0.01, 0.05, 0.1, 0.001],
        'n_estimators': [3,5,7,10,20, 50, 100, 200, 300]
    }

    # Setup GridSearchCV
    grid_search_lgbm = GridSearchCV(estimator=lgbm, param_grid=param_grid_lgbm, 
                                    cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

    # Perform grid search
    grid_search_lgbm.fit(X, y_train[:,i])

    # Best parameters and score
    print(f"Best parameters (LGBM): {grid_search_lgbm.best_params_}")
    print(f"Best score (LGBM): {-grid_search_lgbm.best_score_}")

    # Test set evaluation
    best_lgbm = grid_search_lgbm.best_estimator_
    test_score_lgbm = best_lgbm.score(X_test, y_test[:,i])
    print(f"Test set score (LGBM): {test_score_lgbm}")
    y_pred_lgbm = best_lgbm.predict(X_test)
    plt.boxplot([y_test[:,i], y_pred_lgbm], labels=['Actual', 'Pred'])
    plt.title(f'LGBM-{df.columns[i+3]} RMSE : {np.sqrt(mean_squared_error(y_test[:,i], y_pred_lgbm))}')
    
    plt.savefig(f'plots/lgbm_{format_filename(df.columns[i+3])}.png')
    plt.show()

# %%
idxs = [8,10,11,14]
for i in range(0,17):
    fit_lgbm(i, X, y_train, X_test, y_test)
    fit_rf(i, X, y_train, X_test, y_test)
    fit_svr(i, X, y_train, X_test, y_test)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.01, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=2; total time=   0.0s[CV] END .learning_rate=0.01, n_estimators=20, num_leaves=31; total time=   0.0s
#
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.01, n_estimators=50, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=31; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=200, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=31; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=31; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=31; total time=   0.0s[CV] END .learning_rate=0.05, n_estimators=10, num_leaves=10; total time=   0.0s
#
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.01, n_estimators=300, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=3, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=3; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=5, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=50; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=20, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=3, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=7, num_leaves=70; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=5, num_leaves=2; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=20; total time=   0.0s
# [CV] END ...learning_rate=0.05, n_estimators=7, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=50; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=10; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=10, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END learning_rate=0.01, n_estimators=300, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=10, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=31; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=31; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=200, num_leaves=2; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=200, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=200, num_leaves=10; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END learning_rate=0.05, n_estimators=100, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=70; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=300, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=5; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=50, num_leaves=20; total time=   0.0s
# [CV] END ..learning_rate=0.05, n_estimators=50, num_leaves=3; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=20; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=20, num_leaves=50; total time=   0.0s
# [CV] END .learning_rate=0.05, n_estimators=100, num_leaves=5; total time=   0.0s
# ...
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END max_depth=20, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, min_samples_split=10, n_estimators=300; total time=   0.2s
# Best parameters (RF): {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# Best score (RF): 1605.2901061884434
# Test set score (RF): 0.9030669535398432
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ......................C=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .....................C=10, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .....................C=10, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .....................C=10, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END .....................C=0.1, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=100, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ....................C=100, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, gamma=auto, kernel=poly; total time=   0.4s
# [CV] END .....................C=0.1, gamma=auto, kernel=poly; total time=   0.3s
# [CV] END .....................C=0.1, gamma=auto, kernel=poly; total time=   0.1s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time=   0.4s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time=   1.5s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time=   2.5s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time=   1.2s
# [CV] END .....................C=100, gamma=auto, kernel=poly; total time=   3.4s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time=   4.3s
# [CV] END .....................C=100, gamma=auto, kernel=poly; total time=   4.3s
# [CV] END .....................C=100, gamma=auto, kernel=poly; total time=   5.2s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time=   4.6s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time=  17.4s
# [CV] END .....................C=100, gamma=auto, kernel=poly; total time=  27.9s
# [CV] END .....................C=100, gamma=auto, kernel=poly; total time=  42.8s
# [CV] END ......................C=10, gamma=auto, kernel=poly; total time=  19.8s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time=  47.3s
# [CV] END .......................C=1, gamma=auto, kernel=poly; total time=   5.0s
# Best parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Best score: 2047.3703490083506
# Test set score: 0.867480264449774
